# %% [markdown]
# ## A2A Client to Interact with Our Server

# %%
# %pip install a2a-sdk==0.3.8 azure-ai-projects==2.0.0b2 python-dotenv azure-identity uvicorn
# Out:
# Requirement already satisfied: a2a-sdk==0.3.8 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (0.3.8)
# Requirement already satisfied: azure-ai-projects==2.0.0b2 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (2.0.0b2)
# Requirement already satisfied: python-dotenv in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (1.2.1)
# Requirement already satisfied: azure-identity in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (1.26.0b1)
# Requirement already satisfied: uvicorn in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (0.38.0)
# Requirement already satisfied: google-api-core>=1.26.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from a2a-sdk==0.3.8) (2.28.1)
# Requirement already satisfied: httpx-sse>=0.4.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from a2a-sdk==0.3.8) (0.4.3)
# Requirement already satisfied: httpx>=0.28.1 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from a2a-sdk==0.3.8) (0.28.1)
# Requirement already satisfied: protobuf>=5.29.5 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from a2a-sdk==0.3.8) (5.29.5)
# Requirement already satisfied: pydantic>=2.11.3 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from a2a-sdk==0.3.8) (2.12.5)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from azure-ai-projects==2.0.0b2) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from azure-ai-projects==2.0.0b2) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from azure-ai-projects==2.0.0b2) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from azure-ai-projects==2.0.0b2) (12.28.0b1)
# Requirement already satisfied: cryptography>=2.5 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from azure-identity) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.5)
# Requirement already satisfied: colorama in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk==0.3.8) (1.72.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk==0.3.8) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk==0.3.8) (2.43.0)
# Requirement already satisfied: anyio in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.28.1->a2a-sdk==0.3.8) (4.12.0)
# Requirement already satisfied: certifi in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.28.1->a2a-sdk==0.3.8) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.28.1->a2a-sdk==0.3.8) (1.0.9)
# Requirement already satisfied: idna in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.28.1->a2a-sdk==0.3.8) (3.11)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.11.3->a2a-sdk==0.3.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.11.3->a2a-sdk==0.3.8) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.11.3->a2a-sdk==0.3.8) (0.4.2)
# Requirement already satisfied: pycparser in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk==0.3.8) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk==0.3.8) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk==0.3.8) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.6.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\xsr89\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk==0.3.8) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Importing Libraries and Utilities

# %%
import logging

from typing import Any
from uuid import uuid4

import httpx

from a2a.client import A2ACardResolver, A2AClient
from a2a.types import (
    AgentCard,
    MessageSendParams,
    SendMessageRequest,
    SendStreamingMessageRequest,
)

# %% [markdown]
# ### A2A Client Setup and Implementation

# %%
import uuid
from httpx import AsyncClient
from a2a.types import AgentCard, Message, Part, Role, Task, TextPart
from a2a.client import ClientFactory, Client
from a2a.client.card_resolver import A2ACardResolver
from a2a.client.client import ClientConfig
from a2a.types import TransportProtocol
from a2a.client import create_text_message_object
from a2a.utils.message import get_message_text

base_url = "http://localhost:8080"

# creating the httpx client with custom timeouts
async with httpx.AsyncClient(
    timeout=httpx.Timeout(
        connect=10.0,
        read=60.0,
        write=10.0,
        pool=10.0,
            )) as httpx_client:
    
    # creating the A2ACardResolver
    resolver = A2ACardResolver(
        httpx_client=httpx_client,
        base_url=base_url
    )

    final_agent_card_to_use: AgentCard | None = None

    try:
        # Attempting to fetch public agent card from custom path
        _public_card = (
                await resolver.get_agent_card()
            )  # Fetches from default public path

        final_agent_card_to_use = _public_card

    except Exception as e:
        print(f'Critical error fetching public agent card: {e}', exc_info=True)  
        raise RuntimeError(
                'Failed to fetch the public agent card. Cannot continue.'
            ) from e

    # initializing the A2A Client (ClientFactory Class) config
    config = ClientConfig(
        httpx_client = httpx_client,
        supported_transports=[
                    TransportProtocol.jsonrpc
        ],
        streaming=True
    )
    
    # Creating the A2A Client - Client Factory
    client = ClientFactory(config).create(final_agent_card_to_use)
    
    # Creating the message request
    request = create_text_message_object(content="hey how AI impacted in last 3 months to Tech industry in India & globe")

    # Send the request and get the streaming messages
    async for response in client.send_message(request):
                task, _ = response
                print(get_message_text(task.artifacts[-1]), end = "", flush = True)
# Out:
# Here’s a comprehensive and structured analysis of how artificial intelligence (AI) has impacted the tech industry—both in India and globally—over the past three months (approximately March through May 2026). The insights below are based on recent developments and data, organized by major themes:
#
# ---
#
# ##  India: Rapid Acceleration in Infrastructure, Governance, and Economic Strategy
#
# **Massive Investment Commitments and Infrastructure Build‑out**
# - At the India AI Impact Summit in New Delhi (February 19–20, 2026), Indian conglomerates and public sector actors unveiled over USD 200 billion in planned investments across AI infrastructure over the next several years. Reliance Industries alone committed around USD 110 billion toward data centers, edge computing, and AI services via its Jio platform; Adani Group pledged an additional USD 100 billion for AI data centers. ([forbes.com](https://www.forbes.com/sites/ronschmelzer/2026/02/20/india-ramps-up-ai-infrastructure-investment-with-200-billion-target/))
# - In a related announcement, Union IT Minister Ashwini Vaishnaw confirmed that India is targeting investments across all layers of the AI stack, underpinned by its clean energy edge—with approximately 51% of power generation capacity deriving from clean sources. ([business-standard.com](https://www.business-standard.com/technology/tech-news/india-ai-impact-summit-2026-ashwini-vaishnaw-investments-infra-tech-126021700659_1.html))
# - The event also spotlighted strategic partnerships with global tech players, such as OpenAI and AMD, working alongside Tata Group to scale AI compute, including plans to build up to 1 gigawatt of AI capacity. ([forbes.com](https://www.forbes.com/sites/ronschmelzer/2026/02/20/india-ramps-up-ai-infrastructure-investment-with-200-billion-target/))
#
# **Policy, Governance, and Ecosystem Strategy**
# - The World Economic Forum highlighted that AI sovereignty, governance, and sustainability were central to conversations at the Summit—emphasizing AI as a competitiveness lever and the need for adaptive regulatory frameworks in emerging economies like India. ([weforum.org](https://www.weforum.org/stories/2026/03/ai-india-impact-summit/))
# - India’s government-backed AI strategy (IndiaAI Mission) encompasses seven pillars—ranging from building compute capacity and AI talent development to ensuring safe and trusted AI—aimed at fostering inclusive growth across all tiers of society. ([indiaai.gov.in](https://indiaai.gov.in/))
#
# **Economic Projections and Sector Value Potential**
# - A PwC India report introduced the “AI Edge for Viksit Bharat” framework, projecting that AI could deliver up to USD 550 billion of value to sectors including agriculture, education, energy, healthcare, and manufacturing by 2035. ([pwc.in](https://www.pwc.in/press-releases/2026/pwc-india-unveils-ai-framework.html))
# - An IBM–IndiaAI study released in May 2026 estimates that AI could contribute over USD 500 billion to India’s economy by 2030, with 80% of Indian business leaders believing AI investments will directly influence the nation's economic trajectory. ([in.newsroom.ibm.com](https://in.newsroom.ibm.com/AI-To-Power-India-Next-Economic-Leap))
#
# **Talent and Governance Readiness**
# - Despite these ambitions, 72% of surveyed organizations in India acknowledge being behind global peers in AI adoption—highlighting a gap between ambition and execution that must be closed for effective scale-up. ([in.newsroom.ibm.com](https://in.newsroom.ibm.com/AI-To-Power-India-Next-Economic-Leap))
#
# ---
#
# ##  Global Impact: Adoption, Model Advancement, Corporate Strategy, and Workforce Trends
#
# **Accelerating AI Adoption and Enterprise Integration**
# - Microsoft’s Global AI Diffusion Report shows that global AI usage among working-age individuals rose from 16.3% to 17.8% in Q1 2026; in high-adoption economies, over 30% of working-age populations now use AI. The gap between the Global North (27.5%) and Global South (15.4%) is widening. ([blogs.microsoft.com](https://blogs.microsoft.com/on-the-issues/2026/05/07/the-state-of-global-ai-diffusion-in-2026/))
# - NVIDIA’s “State of AI” report indicates that 64% of surveyed companies are actively using AI, a steady increase across various industries worldwide, including fintech, retail, healthcare, and manufacturing. ([blogs.nvidia.com](https://blogs.nvidia.com/blog/state-of-ai-report-2026/))
# - Deloitte’s 2026 report notes that worker access to AI rose 50% in 2025; the number of companies with at least 40% of AI projects in production is expected to double within six months—signaling rapid movement from pilot to scale. However, only about a third of organizations are deeply redesigning business processes around AI. ([deloitte.com](https://www.deloitte.com/us/en/what-we-do/capabilities/applied-artificial-intelligence/content/state-of-ai-in-the-enterprise.html))
# - KPMG’s Q1 2026 Global AI Pulse emphasizes a shift from experimentation toward orchestration: organizations leading in AI are those embedding governance, talent alignment, and data infrastructure systems to deliver measurable outcomes at scale. ([assets.kpmg.com](https://assets.kpmg.com/content/dam/kpmgsites/xx/pdf/2026/04/global-ai-pulse.pdf))
#
# **Frontier Model Advancements and Funding Surge**
# - April 2026 marked an unprecedented wave of model releases: OpenAI launched GPT‑5.4 (a unified frontier model excelling across coding, reasoning, and knowledge work), while Anthropic and Google DeepMind also released significant new models. ([kersai.com](https://kersai.com/ai-breakthroughs-april-2026-models-funding-shifts/))
# - Q1 2026 saw AI startup ecosystem engulf USD 242 billion—81% of global VC funding. Notable rounds included OpenAI raising USD 122 billion, Anthropic USD 30 billion, xAI USD 20 billion, and Waymo USD 16 billion; SpaceX acquired xAI for USD 250 billion, forming a vertically integrated AI-powered entity valued at USD 1.25 trillion. ([kersai.com](https://kersai.com/ai-breakthroughs-april-2026-models-funding-shifts/))
#
# **Enterprise Use Cases and Agentic AI**
# - Reports indicate agentic AI (AI systems that act autonomously on real-world tasks) has transitioned from pilot demos to production at thousands of companies globally. ([buildfastwithai.com](https://www.buildfastwithai.com/blogs/collection/ai-industry-news-trends))
# - Microsoft’s “What’s Next in AI” trends for 2026 point to AI agents becoming digital collaborators—virtual teammates tackling data crunching, content generation, and personalized tasks, with humans providing strategy and creative direction. ([news.microsoft.com](https://news.microsoft.com/source/emea/features/whats-next-in-ai-7-trends-2026/))
# - However, KPMG’s Global Tech Report indicates only 24% of AI use cases globally are achieving ROI across multiple implementations, underscoring governance and organizational alignment as keys to value realization. ([kpmg.com](https://kpmg.com/xx/en/our-insights/ai-and-technology/global-tech-report.html))
#
# **Workforce Impact and Job Displacement**
# - Early 2026 saw significant layoffs attributed to AI. Block eliminated 4,000 jobs (~40% of its workforce), citing AI’s capacity to automate a wider range of tasks; Oracle laid off between 20,000 to 30,000 employees, redirecting freed capital toward AI data centers. Over 45,000 tech jobs were cut in Q1 2026, with at least 20% directly citing AI as the driver. ([tech-insider.org](https://tech-insider.org/tech-layoffs-2026-ai-workforce-impact/))
#
# ---
#
# ## Comparative Snapshot: India vs. Global Trends
#
# | Dimension                    | India (Past 3 Months)                                                                       | Global (Past 3 Months)                                                                 |
# |------------------------------|----------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------|
# | Investment & Infrastructure  | USD 200B+ in pledges; focus on data centers, edge compute, clean energy, and AI stack layer | Massive VC funding; hyperscale investments from global players                         |
# | Governance & Strategy        | AI sovereignty, inclusive growth frameworks, IndiaAI Mission, 3A2I by PwC, IBM economic plans| Shift to AI orchestration, governance central to scale                                  |
# | Adoption & Enterprise Use    | Strategic intent for inclusive AI across critical sectors                                   | Widespread enterprise adoption; rise of agentic AI; productivity improvements           |
# | Talent & Economic Outlook    | Significant projections; India aiming for global AI leadership by 2030                      | Agencies quantify growth (Microsoft, Deloitte, KPMG); global economic and workforce shifts|
# | Workforce Disruption         | Not yet leading layoffs; focus remains on growth and infrastructure                         | Real-world job displacement and redeployment accelerating across major firms             |
#
# ---
#
# ###  Summary
#
# Over the last three months, **India’s tech industry** has been reshaped by:
#
# - Monumental infrastructure commitments and plans to democratize compute access,
# - Strategic frameworks emphasizing inclusive, trusted, and governance-aware AI growth,
# - Economic studies forecasting that AI could contribute USD 500–550 billion to the Indian economy by 2030–35.
#
# Globally, AI continues its rapid ascent through:
#
# - Explosive funding and frontier model launches,
# - Enterprise deployments moving from pilots to production,
# - A rising cadre of agentic AI systems collaborating with humans,
# - Emerging policy and governance imperatives to manage complexity and risk,
# - Notable workforce impacts in large tech organizations.
#
# As of early June 2026, these trends collectively underscore AI’s evolution from experimentation to foundational infrastructure—reshaping strategy, operations, economics, and governance in both India and across the world.
#
# ---
#
# Let me know if you’d like deep dives into any specific region, sector—like healthcare or manufacturing—or policies and frameworks emerging in India or globally!Here’s an in‑depth, precisely structured overview([forbes.com](https://www.forbes.com/sites/ronschmelzer/2026/02/20/india-ramps-up-ai-infrastructure-investment-with-200-billion-target/))([business-standard.com](https://www.business-standard.com/technology/tech-news/india-ai-impact-summit-2026-ashwini-vaishnaw-investments-infra-tech-126021700659_1.html))([forbes.com](https://www.forbes.com/sites/ronschmelzer/2026/02/20/india-ramps-up-ai-infrastructure-investment-with-200-billion-target/))([weforum.org](https://www.weforum.org/stories/2026/03/ai-india-impact-summit/))([indiaai.gov.in](https://indiaai.gov.in/))([pwc.in](https://www.pwc.in/press-releases/2026/pwc-india-unveils-ai-framework.html))([in.newsroom.ibm.com](https://in.newsroom.ibm.com/AI-To-Power-India-Next-Economic-Leap))([in.newsroom.ibm.com](https://in.newsroom.ibm.com/AI-To-Power-India-Next-Economic-Leap))([blogs.microsoft.com](https://blogs.microsoft.com/on-the-issues/2026/05/07/the-state-of-global-ai-diffusion-in-2026/))([blogs.nvidia.com](https://blogs.nvidia.com/blog/state-of-ai-report-2026/))([deloitte.com](https://www.deloitte.com/us/en/what-we-do/capabilities/applied-artificial-intelligence/content/state-of-ai-in-the-enterprise.html))([assets.kpmg.com](https://assets.kpmg.com/content/dam/kpmgsites/xx/pdf/2026/04/global-ai-pulse.pdf))([kersai.com](https://kersai.com/ai-breakthroughs-april-2026-models-funding-shifts/))([kersai.com](https://kersai.com/ai-breakthroughs-april-2026-models-funding-shifts/))([buildfastwithai.com](https://www.buildfastwithai.com/blogs/collection/ai-industry-news-trends))([news.microsoft.com](https://news.microsoft.com/source/emea/features/whats-next-in-ai-7-trends-2026/))([kpmg.com](https://kpmg.com/xx/en/our-insights/ai-and-technology/global-tech-report.html))([tech-insider.org](https://tech-insider.org/tech-layoffs-2026-ai-workforce-impact/))/tech-layoffs-2026-ai-workforce-impact/)).org/tech-layoffs-2026-ai-workforce-impact/))sider.org](https://tech-insider.org/tech-layoffs-2026-ai-workforce-impact/))logy/global-tech-report.html))([tech-insider.org](https://tech-insider.org/tech-layoffs-2026-ai-workforce-impact/))s://tech-insider.org/tech-layoffs-2026-ai-workforce-impact/)))([tech-insider.org](https://tech-insider.org/tech-layoffs-2026-ai-workforce-impact/))([tech-insider.org](https://tech-insider.org/tech-layoffs-2026-ai-workforce-impact/))bal-tech-report.html))([tech-insider.org](https://tech-insider.org/tech-layoffs-2026-ai-workforce-impact/))-insider.org](https://tech-insider.org/tech-layoffs-2026-ai-workforce-impact/))ech-insider.org](https://tech-insider.org/tech-layoffs-2026-ai-workforce-impact/))h-insider.org/tech-layoffs-2026-ai-workforce-impact/)).
#
# - The summit convened over **89 countries**, culminating in a **global declaration** endorsing AI sovereignty, inclusive innovation, and governance frameworks. This marks one of the broadest collective AI policy alignments to date ([government.economictimes.indiatimes.com](https://government.economictimes.indiatimes.com/news/digital-india/india-ai-impact-summit-2026-how-india-is-shaping-a-sovereign-democratic-and-global-ai-powerhouse/128736978)).
#
# - **Prime Minister Narendra Modi** articulated a vision centered on democratizing AI—‘M.A.N.A.V.’ (Moral and Ethical Systems, Accountable Governance, National Sovereignty, Accessible & Inclusive, Valid & Legitimate)—and emphasized AI's role in serving welfare and progress for all ([pmindia.gov.in](https://www.pmindia.gov.in/en/news_updates/pm-inaugurates-india-ai-impact-summit-2026/)).
#
# Beyond the summit:
#
# - The **India Deep Tech Alliance’s inaugural report** revealed a **58 percent year-over-year surge** in AI funding in 2025, with **$1.22 billion across 188 deals**; additionally, the alliance committed **$1 billion** over the next three years specifically for AI startups ([prnewswire.com](https://www.prnewswire.com/in/news-releases/india-deep-tech-alliance-issues-inaugural-report-showing-ai-funding-jumps-58-in-2025-fast-tracks-1b-usd-investment-to-ai-startup-funding-302689246.html)).
#
# - **IBM India**, via a study released on **May 13, 2026**, projected that AI could contribute over **$500 billion to India’s economy by 2030**, signaling a shift toward AI as a foundational economic driver ([in.newsroom.ibm.com](https://in.newsroom.ibm.com/AI-To-Power-India-Next-Economic-Leap)).
#
# - Leadership from the **IndiaAI Mission** framed India’s approach around democratizing compute, enhancing data quality, fostering indigenous capabilities, establishing AI financing, and ensuring ethical, trusted systems ([indiaai.gov.in](https://indiaai.gov.in/)).
#
# - At the grassroots level, **homegrown AI startups** witnessed significant momentum. Krutrim AI, for example, deployed indigenous AI hardware and multilingual models, while Sarvam AI is building a 120B-parameter sovereign LLM under IndiaAI Mission support ([aifundingtracker.com](https://aifundingtracker.com/top-ai-startups-india/)).
#
# **Summary for India**:
#
# - Massive public and private investment pledges illustrate India's long-term strategic push toward AI sovereignty and infrastructure.
# - Policy frameworks are aligning with “AI for all” ambitions, backed by global declarations and sovereign imperatives.
# - Growing early-stage funding and startup innovation reflect a maturing domestic AI ecosystem.
#
# ---
#
# ### Global Impact: Model Advances, Funding Surges, Enterprise Adoption, and Policy Momentum
#
# #### 1. Frontier Model Releases & Record Funding
#
# - **April 2026 emerged as a pivotal month** for AI. Global startup investment in Q1 2026 reached a record **$297 billion**, with **AI-focused firms capturing $242 billion (81 percent)** of that capital. Remarkably, OpenAI alone raised **$122 billion**, Anthropic secured **$30 billion**, xAI obtained **$20 billion**, and Waymo raised **$16 billion**. Notably, **SpaceX acquired xAI** for **$250 billion**, creating a combined entity valued at **$1.25 trillion** ([kersai.com](https://kersai.com/ai-breakthroughs-april-2026-models-funding-shifts/)).
#
# - Simultaneously, **frontier AI models**—such as **GPT‑5.4**, **Claude Mythos 5**, and **Gemini 3.1 Pro**—exceeded human-level performance across multiple professional domains, indicating rapid leaps in technical capability ([kersai.com](https://kersai.com/ai-breakthroughs-april-2026-models-funding-shifts/)).
#
# #### 2. Hardware Innovation & Global Deployments
#
# - In **May 2026**, **AMD** began production of 6th-generation **EPYC “Venice” processors** using **2nm process technology**, a first in high-performance computing and a direct challenge to NVIDIA’s dominance in AI compute ([crescendo.ai](https://www.crescendo.ai/news/latest-ai-news-and-updates)).
#
# - Across various countries, **AI sovereignty** and domestic chip strategies were gaining traction. The **UK** advanced national chip plans, and **Saudi Arabia** declared **2026 as the “Year of AI”**, emphasizing infrastructure, training, and collaboration ([aicritique.org](https://www.aicritique.org/us/2026/06/01/ai-developments-in-may-2026/)).
#
# #### 3. Enterprise Accelerated Adoption & Agents
#
# - While summaries from **Crescendo Live** and other sources note numerous AI breakthroughs across business, education, and tools between March and May 2026, specific details were general ([crescendo.ai](https://www.crescendo.ai/news/latest-ai-news-and-updates)).
#
# - Reports from Devflokers captured a shift toward **agentic orchestration**, physical AI applications, and large-scale deployments during early May—signaling movement from pilot programs to industrial-scale solutions ([devflokers.com](https://www.devflokers.com/blog/ai-tech-breakthroughs-may-2026-developments)).
#
# #### 4. Policy, Regulation & Sovereign AI
#
# - Global attention to **AI sovereignty** was accelerating. Policymakers increasingly viewed coordinated standards and regulations as competitive assets, not just compliance measures. Telecom operators began considering roles as infrastructure providers in the AI value chain ([weforum.org](https://www.weforum.org/stories/2026/03/ai-india-impact-summit/)).
#
# - A timeline of AI developments through **May 23, 2026**, underscores rapid progress in model launches, funding, regulatory moves, enterprise agents, and the expanding jobs debate ([aiunpacking.com](https://aiunpacking.com/guides/ai-news-2026-timeline-major-developments/)).
#
# ---
#
# ### Comparative Overview: India vs. Global Trends (March–May 2026)
#
# India (March–May 2026):
#
# - Dominated by **summit-driven policy**, infrastructure pledges, and a sovereign AI agenda.
# - Over **US $200 billion** in private-sector pledges, government **$1 billion startup fund**, and ecosystem activation via IndiaAI Mission.
# - Clear trajectory toward inclusive, ethical, sovereign AI at national scale.
#
# Global (March–May 2026):
#
# - Marked by **unprecedented funding rounds**—OpenAI, Anthropic, xAI, Waymo—fueling frontier capabilities.
# - Frontier model performance surged; energy and hardware advances continued (AMD’s 2nm EPYC).
# - Growing emphasis on national AI strategies, enterprise deployment of agentic systems, and emerging regulation.
#
# ---
#
# ### Closing Synthesis
#
# Over the past three months:
#
# - **India** has rapidly elevated its profile on the global AI stage through summit-hosted diplomacy, grand infrastructure commitments, startup funding acceleration, and institutional frameworks aiming to deliver AI for economic and social transformation.
#
# - **Globally**, the AI space has entered a new phase: **record capital inflows**, **superhuman-scale models**, **hardware breakthroughs**, and a strategic policy shift toward sovereignty and regulation.
#
# If you’d like a deep dive into any particular aspect—such as enterprise applications globally, hardware innovations, or India’s policy architecture—just let me know! policy architecture—just let me know!
